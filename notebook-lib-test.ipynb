# %% [markdown]
# # Lux AI Season 2 Tutorial - Python Kit
#
# Welcome to Lux AI Season 2!
#
# This notebook is the basic setup to use Jupyter Notebooks and the kaggle-environments package to develop your bot. If you plan to not use Jupyter Notebooks or any other programming language, please see our Github. The following are some important links!
#
# Competition Page: https://www.kaggle.com/c/lux-ai-season-2/
#
# Online Visualizer: https://s2vis.lux-ai.org/
#
# Specifications: https://www.lux-ai.org/specs-s2
#
# Github: https://github.com/Lux-AI-Challenge/Lux-Design-S2
#
# Bot API: https://github.com/Lux-AI-Challenge/Lux-Design-S2/tree/main/kits
#
# And if you haven't done so already, we highly recommend you join our Discord server at https://discord.gg/aWJt3UAcgn or at the minimum follow the kaggle forums at https://www.kaggle.com/c/lux-ai-season-2/discussion. We post important announcements there such as changes to rules, events, and opportunities from our sponsors!
#
# Now let's get started!

# %% [markdown]
# ## Prerequisites
# We assume that you have a basic knowledge of Python and programming. It's okay if you don't know the game specifications yet! Feel free to always refer back to https://www.lux-ai.org/specs-s2.
#
# ## Basic Setup
# First thing to verify is that you have python 3.7 or above and have the [luxai_s2](https://pypi.org/project/luxai_s2/) package installed

# %%
# verify version
# !python --version
# !pip install --upgrade luxai_s2
# !pip install importlib-metadata==4.13.0
# !pip install --upgrade moviepy

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from luxai_s2.env import LuxAI_S2
import matplotlib.pyplot as plt
import numpy as np
from adl.debugger import Debugger
from agent import Agent
from lux.kit import obs_to_game_state, GameState, EnvConfig
from luxai_s2.utils import animate
from lux.utils import direction_to, my_turn_to_place_factory
from adl.kit import animate, interact

# %% [markdown]
# We can now create an environment and start interacting with it, as well as look at what the observation is like

# %%
env = LuxAI_S2() # create the environment object
obs = env.reset(seed=41) # resets an environment with a seed

# %%
# the observation is always composed of observations for both players.
obs.keys(), obs["player_0"].keys()
# Out:
# (dict_keys(['player_0', 'player_1']),
#  dict_keys(['units', 'teams', 'factories', 'board', 'real_env_steps', 'global_id']))

# %% [markdown]
# To visualize the environment, on jupyter notebooks you have two options
#
# With the `rgb_array` mode you can visualize every step as an environment episode progresses.
#
# With the CLI tool, you can run an episode and save a replay.json to upload to https://s2vis.lux-ai.org/ or a replay.html file to directly open and watch

# %%
# visualize the environment so far with rgb_array to get a quick look at the map
# dark orange - high rubble, light orange - low rubble
# blue = ice, yellow = ore
img = env.render("rgb_array", width=640, height=640)
plt.imshow(img)

# %% [markdown]
# Each team gets `N` factories to place, with. For conveniency the observation contains all possible spawn locations for your team

# %% [markdown]
# #### Building Robots
#
# Only factories can build robots, so for each factory on our team, if there is enough metal and power, we will issue a command to build a new heavy robot.
#
# More advanced strategies will be able to efficiently leverage light units as well to collect resources but for simplicity, this tutorial uses heavy robots since they don't need to move as often to collect many resources (albeit very energy inefficient).

# %%
from lux.kit import obs_to_game_state, GameState
import logging
logging.basicConfig(level=logging.INFO)

# %%
# recreate our agents and run
agents = {player: Agent(player, env.state.env_cfg) for player in env.agents}
animation, obs = interact(env, agents, 15)
animation
# Out:
# INFO:player_0:player_0 has 600 water and 600 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 0.0
# INFO:player_0:player_0 exiting factories 0
# INFO:player_1:player_1 has 600 water and 600 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 240.0
# INFO:player_1:player_1 exiting factories 0
# INFO:player_0:player_0 has 450 water and 450 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 480.0
# INFO:player_0:player_0 exiting factories 1
# INFO:player_1:player_1 has 450 water and 450 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 720.0
# INFO:player_1:player_1 exiting factories 1
# INFO:player_0:player_0 has 300 water and 300 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 960.0
# INFO:player_0:player_0 exiting factories 2
# INFO:player_1:player_1 has 300 water and 300 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 1200.0
# INFO:player_1:player_1 exiting factories 2
# INFO:player_0:player_0 has 150 water and 150 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 1440.0
# INFO:player_0:player_0 exiting factories 3
# INFO:player_1:player_1 has 150 water and 150 metal
# maxFactoriesPerPlayer 4
# maxFactoriesPerPlayer 4
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1796
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1714
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1636
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1551
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1496
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1426
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1398
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 1680.0
# INFO:player_1:player_1 exiting factories 3
# INFO:player_0:{self.player} Building a heavy
# INFO:player_0:{self.player} Building a heavy
# INFO:player_0:{self.player} Building a heavy
# INFO:player_0:{self.player} Building a heavy
# INFO:player_1:{self.player} Building a heavy
# INFO:player_1:{self.player} Building a heavy
# INFO:player_1:{self.player} Building a heavy
# INFO:player_1:{self.player} Building a heavy
# maxFactoriesPerPlayer 4
# targetLichens 960.0
# lichenPerFactory 240.0
# factoriesNeeded 4.0
# resourcePerFactory 150.0
# potential spawn 1359
# <video src="KexIGmNEnuusmKdRTm.webm" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
debugger = Debugger()
debugger.printAgentStates(agents['player_0'], 0, obs['player_0'])
debugger.printOpponentStates(agents['player_0'], 0, obs['player_0'])
# Out:
# faction: AlphaStrike
# 	team_id: 0
# 	agent: player_0
# 	water: 0
# 	metal: 0
# 	factories_to_place: 0
# 	factory_strains: [0, 2, 4, 6]
# #factories: 4
# 	unit_id: factory_0
# 	strain_id: 0
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [17 17]
# 	unit_id: factory_2
# 	strain_id: 2
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [36 27]
# 	unit_id: factory_4
# 	strain_id: 4
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [24 12]
# 	unit_id: factory_6
# 	strain_id: 6
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [36  5]
# #units: 4
# 	unit_id: unit_8
# 	unit_type: HEAVY
# 	power: 135
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [14 15]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_9
# 	unit_type: HEAVY
# 	power: 67
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [32 28]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_10
# 	unit_type: HEAVY
# 	power: 163
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [27 10]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_11
# 	unit_type: HEAVY
# 	power: 273
# 	cargo: UnitCargo(ice=40, ore=0, water=0, metal=0)
# 	pos: [34  5]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# faction: AlphaStrike
# 	team_id: 1
# 	agent: player_1
# 	water: 0
# 	metal: 0
# 	factories_to_place: 0
# 	factory_strains: [1, 3, 5, 7]
# #factories: 4
# 	unit_id: factory_1
# 	strain_id: 1
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [14 42]
# 	unit_id: factory_3
# 	strain_id: 3
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [26 26]
# 	unit_id: factory_5
# 	strain_id: 5
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [46  1]
# 	unit_id: factory_7
# 	strain_id: 7
# 	power: 800
# 	cargo: UnitCargo(ice=0, ore=0, water=144, metal=50)
# 	pos: [ 7 40]
# #units: 4
# 	unit_id: unit_12
# 	unit_type: HEAVY
# 	power: 30
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [16 39]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_13
# 	unit_type: HEAVY
# 	power: 347
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [28 29]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_14
# 	unit_type: HEAVY
# 	power: 105
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [41  1]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []
# 	unit_id: unit_15
# 	unit_type: HEAVY
# 	power: 379
# 	cargo: UnitCargo(ice=0, ore=0, water=0, metal=0)
# 	pos: [ 5 37]
# 	unit_cfg: UnitConfig(METAL_COST=100, POWER_COST=500, CARGO_SPACE=1000, BATTERY_CAPACITY=3000, CHARGE=10, INIT_POWER=500, MOVE_COST=20, RUBBLE_MOVEMENT_COST=1, DIG_COST=60, DIG_RUBBLE_REMOVED=20, DIG_RESOURCE_GAIN=20, DIG_LICHEN_REMOVED=100, SELF_DESTRUCT_COST=100, RUBBLE_AFTER_DESTRUCTION=10, ACTION_QUEUE_POWER_COST=10)
# 	action_queue: []

# %% [markdown]
# ## Create a submission
# Now we need to create a .tar.gz file with main.py (and agent.py) at the top level. We can then upload this!

# %%
# !tar -czf submission.tar.gz *

# %% [markdown]
# ## Submit
# Now open the /kaggle/working folder and find submission.tar.gz, download that file, navigate to the "MySubmissions" tab in https://www.kaggle.com/c/lux-ai-season-2/ and upload your submission! It should play a validation match against itself and once it succeeds it will be automatically matched against other players' submissions. Newer submissions will be prioritized for games over older ones. Your team is limited in the number of succesful submissions per day so we highly recommend testing your bot locally before submitting.

# %% [markdown]
# ## CLI Tool
#
# To test your agent without using the python API you can also run

# %%
# !luxai-s2 main.py main.py -v 2 -s 101 -o replay.html

# %% [markdown]
# which uses a random seed and generates a replay.html file that you can click and watch. Optionally if you specify `-o replay.json` you can upload replay.json to http://s2vis.lux-ai.org/.
#
# The CLI tool enables you to easily run episodes between any two agents (python or not) and provides a flexible tournament running tool to evaluate many agents together. Documentation on this tool can be found here: https://github.com/Lux-AI-Challenge/Lux-Design-S2/tree/main/luxai_runner/README.md

# %%
# import IPython
# IPython.display.HTML(filename='replay.html')

# %%
np.set_printoptions(threshold=np.inf)
gs = obs_to_game_state(0, env.state.env_cfg, obs["player_0"])
# debugger.printFactories(gs.factories['player_0'])
# debugger.printFactories(gs.factories['player_1'])
# print(gs.board.factory_occupancy_map > -1)
# print(gs.board.rubble > 0)
print(np.unique(gs.board.factory_occupancy_map))
# Out:
# [-1  0  1  2  3  4  5  6  7]

# %%
print(obs["player_0"]["board"]["factories_per_team"])
# Out:
# 4

# %%
a = np.random.randint(-1, 3, size=(4,4))
b = np.random.randint(-1, 3, size=(4,4))
a2 = a > -1
print(a)
print(a2)
print(b)
print(np.logical_or(a, b))
print(np.logical_or(a2, b))
# Out:
# [[ 1 -1  2  1]
#  [-1 -1 -1  1]
#  [ 0  1  2  2]
#  [ 1 -1  0  0]]
# [[ True False  True  True]
#  [False False False  True]
#  [ True  True  True  True]
#  [ True False  True  True]]
# [[ 0  0 -1  0]
#  [-1  2 -1  2]
#  [ 0  1  2  2]
#  [-1  1  2 -1]]
# [[ True  True  True  True]
#  [ True  True  True  True]
#  [False  True  True  True]
#  [ True  True  True  True]]
# [[ True False  True  True]
#  [ True  True  True  True]
#  [ True  True  True  True]
#  [ True  True  True  True]]

# %%
occupied = np.logical_or(a2, b)
np.sum(occupied)
# Out:
# 15

# %%
from adl.board_analysis import BoardAnalyzer
boardAnalyzer = BoardAnalyzer()

# %%
env = LuxAI_S2() # create the environment object
env.reset()
# obs = env.reset() # resets an environment with a seed
# gs = obs_to_game_state(0, env.state.env_cfg, obs["player_0"])
# print("max factory per player", gs.maxFactoriesPerPlayer)
# print("lichen upper bound before setup", boardAnalyzer.getLichenUBBeforeBidding(gs))

agents = {player: Agent(player, env.state.env_cfg) for player in env.agents}
animation, obs = interact(env, agents, 9)
gs = obs_to_game_state(0, env.state.env_cfg, obs["player_0"])
print("lichen upper bound after setup", boardAnalyzer.getLichenUBAfterAfterBidding(gs))

img = env.render("rgb_array", width=640, height=640)
plt.imshow(img)
# Out:
# INFO:player_0:player_0:  maxFactoriesPerPlayer 4
# INFO:player_1:player_1:  maxFactoriesPerPlayer 4
# INFO:player_0:player_0 has 600 water and 600 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 0.0
# INFO:player_0:player_0 exiting factories 0
# INFO:player_0:player_0:  maxFactoriesPerPlayer 4
# INFO:player_0:player_0:  targetLichens 960.0
# INFO:player_0:player_0:  lichenPerFactory 240.0
# INFO:player_0:player_0:  factoriesNeeded 4.0
# INFO:player_0:player_0:  resourcePerFactory 150.0
# INFO:player_0:player_0:  potential spawn 1796
# INFO:player_1:player_1 has 600 water and 600 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 240.0
# INFO:player_1:player_1 exiting factories 0
# INFO:player_1:player_1:  maxFactoriesPerPlayer 4
# INFO:player_1:player_1:  targetLichens 960.0
# INFO:player_1:player_1:  lichenPerFactory 240.0
# INFO:player_1:player_1:  factoriesNeeded 4.0
# INFO:player_1:player_1:  resourcePerFactory 150.0
# INFO:player_1:player_1:  potential spawn 1714
# INFO:player_0:player_0 has 450 water and 450 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 480.0
# INFO:player_0:player_0 exiting factories 1
# INFO:player_0:player_0:  maxFactoriesPerPlayer 4
# INFO:player_0:player_0:  targetLichens 960.0
# INFO:player_0:player_0:  lichenPerFactory 240.0
# INFO:player_0:player_0:  factoriesNeeded 4.0
# INFO:player_0:player_0:  resourcePerFactory 150.0
# INFO:player_0:player_0:  potential spawn 1636
# INFO:player_1:player_1 has 450 water and 450 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 720.0
# INFO:player_1:player_1 exiting factories 1
# INFO:player_1:player_1:  maxFactoriesPerPlayer 4
# INFO:player_1:player_1:  targetLichens 960.0
# INFO:player_1:player_1:  lichenPerFactory 240.0
# INFO:player_1:player_1:  factoriesNeeded 4.0
# INFO:player_1:player_1:  resourcePerFactory 150.0
# INFO:player_1:player_1:  potential spawn 1551
# INFO:player_0:player_0 has 300 water and 300 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 960.0
# INFO:player_0:player_0 exiting factories 2
# INFO:player_0:player_0:  maxFactoriesPerPlayer 4
# INFO:player_0:player_0:  targetLichens 960.0
# INFO:player_0:player_0:  lichenPerFactory 240.0
# INFO:player_0:player_0:  factoriesNeeded 4.0
# INFO:player_0:player_0:  resourcePerFactory 150.0
# INFO:player_0:player_0:  potential spawn 1496
# INFO:player_1:player_1 has 300 water and 300 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 1200.0
# INFO:player_1:player_1 exiting factories 2
# INFO:player_1:player_1:  maxFactoriesPerPlayer 4
# INFO:player_1:player_1:  targetLichens 960.0
# INFO:player_1:player_1:  lichenPerFactory 240.0
# INFO:player_1:player_1:  factoriesNeeded 4.0
# INFO:player_1:player_1:  resourcePerFactory 150.0
# INFO:player_1:player_1:  potential spawn 1426
# INFO:player_0:player_0 has 150 water and 150 metal
# INFO:player_0:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_0:Early Setup:  lichen UB after bidding: 1440.0
# INFO:player_0:player_0 exiting factories 3
# INFO:player_0:player_0:  maxFactoriesPerPlayer 4
# INFO:player_0:player_0:  targetLichens 960.0
# INFO:player_0:player_0:  lichenPerFactory 240.0
# INFO:player_0:player_0:  factoriesNeeded 4.0
# INFO:player_0:player_0:  resourcePerFactory 150.0
# INFO:player_0:player_0:  potential spawn 1398
# INFO:player_1:player_1 has 150 water and 150 metal
# INFO:player_1:Early Setup: lichen UB before bidding: 1920.0
# INFO:player_1:Early Setup:  lichen UB after bidding: 1680.0
# INFO:player_1:player_1 exiting factories 3
# INFO:player_1:player_1:  maxFactoriesPerPlayer 4
# INFO:player_1:player_1:  targetLichens 960.0
# INFO:player_1:player_1:  lichenPerFactory 240.0
# INFO:player_1:player_1:  factoriesNeeded 4.0
# INFO:player_1:player_1:  resourcePerFactory 150.0
# INFO:player_1:player_1:  potential spawn 1359
# lichen upper bound after setup 1920.0

# %%
debugger = Debugger()
debugger.printAgentStates(agents['player_0'], 0, obs['player_0'])
debugger.printOpponentStates(agents['player_0'], 0, obs['player_0'])
# Out:
# faction: AlphaStrike
# 	team_id: 0
# 	agent: player_0
# 	water: 0
# 	metal: 0
# 	factories_to_place: 0
# 	factory_strains: [0, 2, 4, 6]
# #factories: 4
# 	unit_id: factory_0
# 	strain_id: 0
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [17 17]
# 	unit_id: factory_2
# 	strain_id: 2
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [36 27]
# 	unit_id: factory_4
# 	strain_id: 4
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [24 12]
# 	unit_id: factory_6
# 	strain_id: 6
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [36  5]
# #units: 0
# faction: AlphaStrike
# 	team_id: 1
# 	agent: player_1
# 	water: 0
# 	metal: 0
# 	factories_to_place: 0
# 	factory_strains: [1, 3, 5, 7]
# #factories: 4
# 	unit_id: factory_1
# 	strain_id: 1
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [14 42]
# 	unit_id: factory_3
# 	strain_id: 3
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [26 26]
# 	unit_id: factory_5
# 	strain_id: 5
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [46  1]
# 	unit_id: factory_7
# 	strain_id: 7
# 	power: 1000
# 	cargo: UnitCargo(ice=0, ore=0, water=150, metal=150)
# 	pos: [ 7 40]
# #units: 0
